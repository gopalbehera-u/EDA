# %%
import pandas as pd

# %%
dataset=pd.read_csv(r'C:\Users\beher\OneDrive\Desktop\EDA\loan.csv')

# %%
# how ur data looks like 
dataset.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...

# %%
# how big ur data 
dataset.shape
# Out:
# (614, 13)

# %%
dataset.isna().sum()# checking missing value
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
dataset.info()# checking column datatype
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            614 non-null    object
#  1   Gender             601 non-null    object
#  2   Married            611 non-null    object
#  3   Dependents         599 non-null    object
#  4   Education          614 non-null    object
#  5   Self_Employed      582 non-null    object
#  6   ApplicantIncome    614 non-null    int64
#  7   CoapplicantIncome  614 non-null    float64
#  8   LoanAmount         592 non-null    float64
#  9   Loan_Amount_Term   600 non-null    float64
#  10  Credit_History     564 non-null    float64
#  11  Property_Area      614 non-null    object
#  12  Loan_Status        614 non-null    object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 62.5+ KB

# %%
dataset.describe() # how ur dataset looks like matmatically
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       614.000000         614.000000  592.000000         600.00000
# mean       5403.459283        1621.245798  146.412162         342.00000
# std        6109.041673        2926.248369   85.587325          65.12041
# min         150.000000           0.000000    9.000000          12.00000
# 25%        2877.500000           0.000000  100.000000         360.00000
# 50%        3812.500000        1188.500000  128.000000         360.00000
# 75%        5795.000000        2297.250000  168.000000         360.00000
# max       81000.000000       41667.000000  700.000000         480.00000
#
#        Credit_History
# count      564.000000
# mean         0.842199
# std          0.364878
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %%
dataset['Loan_Status'] = dataset['Loan_Status'].map({
    'Y': 1,
    'N': 0
})

# %%
dataset.duplicated().sum()
# Out:
# np.int64(0)

# %%
dataset.corr(numeric_only=True)['Loan_Status']
# Out:
# ApplicantIncome     -0.004710
# CoapplicantIncome   -0.059187
# LoanAmount          -0.037318
# Loan_Amount_Term    -0.021268
# Credit_History       0.561678
# Loan_Status          1.000000
# Name: Loan_Status, dtype: float64

# %% [markdown]
# # univariate analysis

# %%
dataset.columns
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.countplot(data=dataset,x=dataset['Gender'])
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
dataset['Married']
# Out:
# 0       No
# 1      Yes
# 2      Yes
# 3      Yes
# 4       No
#       ...
# 609     No
# 610    Yes
# 611    Yes
# 612    Yes
# 613     No
# Name: Married, Length: 614, dtype: object

# %%
sns.countplot(x=dataset['Married'])
# Out:
# <Axes: xlabel='Married', ylabel='count'>

# %%
plt.pie(
    x=dataset['Loan_Status'].value_counts(),
    labels=dataset['Loan_Status'].value_counts().index,
    autopct="%.2f%%"
)
# Out:
# ([<matplotlib.patches.Wedge at 0x213bf90e990>,
# ...
#  [Text(-0.6105422225368479, 0.9150072100807547, '1'),
#   Text(0.610542084374596, -0.915007302270055, '0')],
#  [Text(-0.33302303047464427, 0.4990948418622298, '68.73%'),
#   Text(0.333022955113416, -0.4990948921473027, '31.27%')])

# %%
# sns.displot(x=dataset[''],bins=3)
